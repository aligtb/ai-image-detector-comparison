# %%
# Install necessary Python packages using pip

# Use the 'pip' command to install packages
# The '-q' flag stands for 'quiet,' which means it will suppress most output, making the installation process less verbose
# We're installing the following packages:
# - 'evaluate': This package is likely used for evaluation purposes, but the specific functionality is not clear from this line alone
# - 'transformers': This package is commonly used for natural language processing tasks, such as working with pre-trained language models like BERT or GPT
# - 'datasets': This package provides easy access to various datasets commonly used in machine learning and natural language processing tasks
# - 'mlflow': MLflow is an open-source platform for managing the end-to-end machine learning lifecycle, including tracking experiments, packaging code into reproducible runs, and sharing and deploying models

# Note: Before running this code, make sure you have Python and pip installed on your system.
# Also, ensure you have an internet connection since pip will download and install these packages from PyPI (Python Package Index).
# !pip install -U -q evaluate transformers datasets>=2.14.5 accelerate>=0.27 mlflow 2>/dev/null

# %%
# Importing necessary libraries and modules
import warnings  # Import the 'warnings' module for handling warnings
warnings.filterwarnings("ignore")  # Ignore warnings during execution

import gc  # Import the 'gc' module for garbage collection
import numpy as np  # Import NumPy for numerical operations
import pandas as pd  # Import Pandas for data manipulation
import itertools  # Import 'itertools' for iterators and looping
from collections import Counter  # Import 'Counter' for counting elements
import matplotlib.pyplot as plt  # Import Matplotlib for data visualization
from sklearn.metrics import (  # Import various metrics from scikit-learn
    accuracy_score,  # For calculating accuracy
    roc_auc_score,  # For ROC AUC score
    confusion_matrix,  # For confusion matrix
    classification_report,  # For classification report
    f1_score  # For F1 score
)

# Import custom modules and classes
from imblearn.over_sampling import RandomOverSampler # import RandomOverSampler
import accelerate # Import the 'accelerate' module
import evaluate  # Import the 'evaluate' module
from datasets import Dataset, Image, ClassLabel  # Import custom 'Dataset', 'ClassLabel', and 'Image' classes
from transformers import (  # Import various modules from the Transformers library
    TrainingArguments,  # For training arguments
    Trainer,  # For model training
    ViTImageProcessor,  # For processing image data with ViT models
    ViTForImageClassification,  # ViT model for image classification
    DefaultDataCollator  # For collating data in the default way
)
import torch  # Import PyTorch for deep learning
from torch.utils.data import DataLoader  # For creating data loaders
from torchvision.transforms import (  # Import image transformation functions
    CenterCrop,  # Center crop an image
    Compose,  # Compose multiple image transformations
    Normalize,  # Normalize image pixel values
    RandomRotation,  # Apply random rotation to images
    RandomResizedCrop,  # Crop and resize images randomly
    RandomHorizontalFlip,  # Apply random horizontal flip
    RandomAdjustSharpness,  # Adjust sharpness randomly
    Resize,  # Resize images
    ToTensor  # Convert images to PyTorch tensors
)

# %%
# !unzip data.zip -d cifake-real-and-ai-generated-synthetic-images
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4500.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4501.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4502.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4503.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4504.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4505.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4506.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4507.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4508.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4509.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4510.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4511.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4512.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4513.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4514.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4515.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4516.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4517.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4518.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4519.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4520.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4521.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4522.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4523.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4524.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4525.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4526.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4527.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4528.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4529.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4530.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4531.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4532.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4533.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4534.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4535.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4536.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4537.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4538.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4539.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4540.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4541.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4542.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4543.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4544.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4545.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4546.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4547.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4548.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4549.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4550.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4551.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4552.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4553.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4554.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4555.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4556 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4556 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4556 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4556 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4556 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4556 (6).jpg
# ...
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4981 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4981 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4981 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4981 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4981 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4981 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4981 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4981.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4982.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4983.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4984.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4985.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4986.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4987.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4988.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4989.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4990.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4991.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4992.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4993.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4994.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4995.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4996.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4997.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4998.jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999 (10).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999 (2).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999 (3).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999 (4).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999 (5).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999 (6).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999 (7).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999 (8).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999 (9).jpg
#   inflating: cifake-real-and-ai-generated-synthetic-images/train/REAL/4999.jpg

# %%
# use https://huggingface.co/docs/datasets/image_load for reference

# Import necessary libraries
image_dict = {}

# Define the list of file names
from pathlib import Path
from tqdm import tqdm
import os
# Initialize empty lists to store file names and labels
file_names = []
labels = []

# Iterate through all image files in the specified directory
for file in sorted((Path('/content/cifake-real-and-ai-generated-synthetic-images/').glob('*/*/*.*'))):
    label = str(file).split('/')[-2]  # Extract the label from the file path
    labels.append(label)  # Add the label to the list
    file_names.append(str(file))  # Add the file path to the list

# Print the total number of file names and labels
print(len(file_names), len(labels))

# Create a pandas dataframe from the collected file names and labels
df = pd.DataFrame.from_dict({"image": file_names, "label": labels})
print(df.shape)
# Out:
# 120000 120000
# (120000, 2)

# %%
df.head()
# Out:
#                                                image label
# 0  /content/cifake-real-and-ai-generated-syntheti...  FAKE
# 1  /content/cifake-real-and-ai-generated-syntheti...  FAKE
# 2  /content/cifake-real-and-ai-generated-syntheti...  FAKE
# 3  /content/cifake-real-and-ai-generated-syntheti...  FAKE
# 4  /content/cifake-real-and-ai-generated-syntheti...  FAKE

# %%
df['label'].unique()
# Out:
# array(['FAKE', 'REAL'], dtype=object)

# %%
# random oversampling of minority class
# 'y' contains the target variable (label) we want to predict
y = df[['label']]

# Drop the 'label' column from the DataFrame 'df' to separate features from the target variable
df = df.drop(['label'], axis=1)

# Create a RandomOverSampler object with a specified random seed (random_state=83)
ros = RandomOverSampler(random_state=83)

# Use the RandomOverSampler to resample the dataset by oversampling the minority class
# 'df' contains the feature data, and 'y_resampled' will contain the resampled target variable
df, y_resampled = ros.fit_resample(df, y)

# Delete the original 'y' variable to save memory as it's no longer needed
del y

# Add the resampled target variable 'y_resampled' as a new 'label' column in the DataFrame 'df'
df['label'] = y_resampled

# Delete the 'y_resampled' variable to save memory as it's no longer needed
del y_resampled

# Perform garbage collection to free up memory used by discarded variables
gc.collect()

print(df.shape)
# Out:
# (120000, 2)

# %%
# Create a dataset from a Pandas DataFrame.
dataset = Dataset.from_pandas(df).cast_column("image", Image())

# %%
# Display the first image in the dataset
dataset[0]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=32x32>

# %%
# Extracting a subset of elements from the 'labels' list using slicing.
# The slicing syntax [:5] selects elements from the beginning up to (but not including) the 5th element.
# This will give us the first 5 elements of the 'labels' list.
# The result will be a new list containing these elements.
labels_subset = labels[:5]

# Printing the subset of labels to inspect the content.
print(labels_subset)
# Out:
# ['FAKE', 'FAKE', 'FAKE', 'FAKE', 'FAKE']

# %%
# Create a list of unique labels by converting 'labels' to a set and then back to a list
labels_list = ['REAL', 'FAKE'] #list(set(labels))

# Initialize empty dictionaries to map labels to IDs and vice versa
label2id, id2label = dict(), dict()

# Iterate over the unique labels and assign each label an ID, and vice versa
for i, label in enumerate(labels_list):
    label2id[label] = i  # Map the label to its corresponding ID
    id2label[i] = label  # Map the ID to its corresponding label

# Print the resulting dictionaries for reference
print("Mapping of IDs to Labels:", id2label, '\n')
print("Mapping of Labels to IDs:", label2id)
# Out:
# Mapping of IDs to Labels: {0: 'REAL', 1: 'FAKE'}
#
# Mapping of Labels to IDs: {'REAL': 0, 'FAKE': 1}

# %%
# Creating classlabels to match labels to IDs
ClassLabels = ClassLabel(num_classes=len(labels_list), names=labels_list)

# Mapping labels to IDs
def map_label2id(example):
    example['label'] = ClassLabels.str2int(example['label'])
    return example

dataset = dataset.map(map_label2id, batched=True)

# Casting label column to ClassLabel Object
dataset = dataset.cast_column('label', ClassLabels)

# Splitting the dataset into training and testing sets using an 60-40 split ratio.
dataset = dataset.train_test_split(test_size=0.4, shuffle=True, stratify_by_column="label")

# Extracting the training data from the split dataset.
train_data = dataset['train']

# Extracting the testing data from the split dataset.
test_data = dataset['test']
# Out:
# Map:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/120000 [00:00<?, ? examples/s]

# %%
# Define the pre-trained ViT model string
model_str = "dima806/ai_vs_real_image_detection" #'google/vit-base-patch16-224-in21k'

# Create a processor for ViT model input from the pre-trained model
processor = ViTImageProcessor.from_pretrained(model_str)

# Retrieve the image mean and standard deviation used for normalization
image_mean, image_std = processor.image_mean, processor.image_std

# Get the size (height) of the ViT model's input images
size = processor.size["height"]
print("Size: ", size)

# Define a normalization transformation for the input images
normalize = Normalize(mean=image_mean, std=image_std)

# Define a set of transformations for training data
_train_transforms = Compose(
    [
        Resize((size, size)),             # Resize images to the ViT model's input size
        RandomRotation(90),               # Apply random rotation
        RandomAdjustSharpness(2),         # Adjust sharpness randomly
        ToTensor(),                       # Convert images to tensors
        normalize                         # Normalize images using mean and std
    ]
)

# Define a set of transformations for validation data
_val_transforms = Compose(
    [
        Resize((size, size)),             # Resize images to the ViT model's input size
        ToTensor(),                       # Convert images to tensors
        normalize                         # Normalize images using mean and std
    ]
)

# Define a function to apply training transformations to a batch of examples
def train_transforms(examples):
    examples['pixel_values'] = [_train_transforms(image.convert("RGB")) for image in examples['image']]
    return examples

# Define a function to apply validation transformations to a batch of examples
def val_transforms(examples):
    examples['pixel_values'] = [_val_transforms(image.convert("RGB")) for image in examples['image']]
    return examples
# Out:
# preprocessor_config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# Size:  224

# %%
# Set the transforms for the training data
train_data.set_transform(train_transforms)

# Set the transforms for the test/validation data
test_data.set_transform(val_transforms)

# %%
# Define a collate function that prepares batched data for model training.
def collate_fn(examples):
    # Stack the pixel values from individual examples into a single tensor.
    pixel_values = torch.stack([example["pixel_values"] for example in examples])

    # Convert the label strings in examples to corresponding numeric IDs using label2id dictionary.
    labels = torch.tensor([example['label'] for example in examples])

    # Return a dictionary containing the batched pixel values and labels.
    return {"pixel_values": pixel_values, "labels": labels}

# %%
# Create a ViTForImageClassification model from a pretrained checkpoint with a specified number of output labels.
model = ViTForImageClassification.from_pretrained(model_str, num_labels=len(labels_list))

# Configure the mapping of class labels to their corresponding indices for later reference.
model.config.id2label = id2label
model.config.label2id = label2id

# Calculate and print the number of trainable parameters in millions for the model.
print(model.num_parameters(only_trainable=True) / 1e6)
# Out:
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]
# 85.800194

# %%
# Load the accuracy metric from a module named 'evaluate'
accuracy = evaluate.load("accuracy")

# Define a function 'compute_metrics' to calculate evaluation metrics
def compute_metrics(eval_pred):
    # Extract model predictions from the evaluation prediction object
    predictions = eval_pred.predictions

    # Extract true labels from the evaluation prediction object
    label_ids = eval_pred.label_ids

    # Calculate accuracy using the loaded accuracy metric
    # Convert model predictions to class labels by selecting the class with the highest probability (argmax)
    predicted_labels = predictions.argmax(axis=1)

    # Calculate accuracy score by comparing predicted labels to true labels
    acc_score = accuracy.compute(predictions=predicted_labels, references=label_ids)['accuracy']

    # Return the computed accuracy as a dictionary with the key "accuracy"
    return {
        "accuracy": acc_score
    }
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]

# %%
# Define the name of the evaluation metric to be used during training and evaluation.
metric_name = "accuracy"

# Define the name of the model, which will be used to create a directory for saving model checkpoints and outputs.
model_name = "ai_vs_real_image_detection"

# Define the number of training epochs for the model.
num_train_epochs = 2

# Create an instance of TrainingArguments to configure training settings.
args = TrainingArguments(
    # Specify the directory where model checkpoints and outputs will be saved.
    output_dir=model_name,

    # Specify the directory where training logs will be stored.
    logging_dir='./logs',

    # Define the evaluation strategy, which is performed at the end of each epoch.
    eval_strategy="epoch",

    # Set the learning rate for the optimizer.
    learning_rate=1e-6,

    # Define the batch size for training on each device.
    per_device_train_batch_size=64,

    # Define the batch size for evaluation on each device.
    per_device_eval_batch_size=32,

    # Specify the total number of training epochs.
    num_train_epochs=num_train_epochs,

    # Apply weight decay to prevent overfitting.
    weight_decay=0.02,

    # Set the number of warm-up steps for the learning rate scheduler.
    warmup_steps=50,

    # Disable the removal of unused columns from the dataset.
    remove_unused_columns=False,

    # Define the strategy for saving model checkpoints (per epoch in this case).
    save_strategy='epoch',

    # Load the best model at the end of training.
    load_best_model_at_end=True,

    # Limit the total number of saved checkpoints to save space.
    save_total_limit=1,

    # Specify that training progress should not be reported .
    report_to="none"  # log to none
)

# %%
# Create a Trainer instance for fine-tuning a language model.

# - `model`: The pre-trained language model to be fine-tuned.
# - `args`: Configuration settings and hyperparameters for training.
# - `train_dataset`: The dataset used for training the model.
# - `eval_dataset`: The dataset used for evaluating the model during training.
# - `data_collator`: A function that defines how data batches are collated and processed.
# - `compute_metrics`: A function for computing custom evaluation metrics.
# - `tokenizer`: The tokenizer used for processing text data.

trainer = Trainer(
    model,
    args,
    train_dataset=train_data,
    eval_dataset=test_data,
    data_collator=collate_fn,
    compute_metrics=compute_metrics,
    tokenizer=processor,
)

# %%
# Evaluate the pre-training model's performance on a test dataset.
# This function calculates various metrics such as accuracy, loss, etc.,
# to assess how well the model is performing on unseen data.

trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='1500' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1500/1500 09:59]
#     </div>
# {'eval_loss': 0.04578448086977005,
#  'eval_model_preparation_time': 0.0029,
#  'eval_accuracy': 0.983375,
#  'eval_runtime': 600.9326,
#  'eval_samples_per_second': 79.876,
#  'eval_steps_per_second': 2.496}

# %%
# Start training the model using the trainer object.
trainer.train()
# Out:
#     <div>
#
#       <progress value='2250' max='2250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2250/2250 1:47:41, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Model Preparation Time</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.039100</td>
#       <td>0.044062</td>
#       <td>0.002900</td>
#       <td>0.983979</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.036300</td>
#       <td>0.043131</td>
#       <td>0.002900</td>
#       <td>0.984292</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='3000' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1500/1500 1:03:22]
#     </div>
# TrainOutput(global_step=2250, training_loss=0.0368557612101237, metrics={'train_runtime': 6464.0027, 'train_samples_per_second': 22.277, 'train_steps_per_second': 0.348, 'total_flos': 1.1158846504501248e+19, 'train_loss': 0.0368557612101237, 'epoch': 2.0})

# %%
# Evaluate the post-training model's performance on the validation or test dataset.
# This function computes various evaluation metrics like accuracy, loss, etc.
# and provides insights into how well the model is performing.

trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='1500' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1500/1500 09:59]
#     </div>
# {'eval_loss': 0.04313144087791443,
#  'eval_model_preparation_time': 0.0029,
#  'eval_accuracy': 0.9842916666666667,
#  'eval_runtime': 600.1284,
#  'eval_samples_per_second': 79.983,
#  'eval_steps_per_second': 2.499,
#  'epoch': 2.0}

# %%
# Use the trained 'trainer' to make predictions on the 'test_data'.
outputs = trainer.predict(test_data)

# Print the metrics obtained from the prediction outputs.
print(outputs.metrics)
# Out:
# {'test_loss': 0.04313144087791443, 'test_model_preparation_time': 0.0029, 'test_accuracy': 0.9842916666666667, 'test_runtime': 601.3206, 'test_samples_per_second': 79.824, 'test_steps_per_second': 2.495}

# %%
# Extract the true labels from the model outputs
y_true = outputs.label_ids

# Predict the labels by selecting the class with the highest probability
y_pred = outputs.predictions.argmax(1)

# Define a function to plot a confusion matrix
def plot_confusion_matrix(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues, figsize=(10, 8)):
    """
    This function plots a confusion matrix.

    Parameters:
        cm (array-like): Confusion matrix as returned by sklearn.metrics.confusion_matrix.
        classes (list): List of class names, e.g., ['Class 0', 'Class 1'].
        title (str): Title for the plot.
        cmap (matplotlib colormap): Colormap for the plot.
    """
    # Create a figure with a specified size
    plt.figure(figsize=figsize)

    # Display the confusion matrix as an image with a colormap
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    # Define tick marks and labels for the classes on the axes
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.0f'
    # Add text annotations to the plot indicating the values in the cells
    thresh = cm.max() / 2.0
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    # Label the axes
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Ensure the plot layout is tight
    plt.tight_layout()
    # Display the plot
    plt.show()

# Calculate accuracy and F1 score
accuracy = accuracy_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred, average='macro')

# Display accuracy and F1 score
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")

# Get the confusion matrix if there are a small number of labels
if len(labels_list) <= 150:
    # Compute the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Plot the confusion matrix using the defined function
    plot_confusion_matrix(cm, labels_list, figsize=(8, 6))

# Finally, display classification report
print()
print("Classification report:")
print()
print(classification_report(y_true, y_pred, target_names=labels_list, digits=4))
# Out:
# Accuracy: 0.9843
# F1 Score: 0.9843
# Classification report:
#
#               precision    recall  f1-score   support
#
#         REAL     0.9845    0.9841    0.9843     24000
#         FAKE     0.9841    0.9845    0.9843     24000
#
#     accuracy                         0.9843     48000
#    macro avg     0.9843    0.9843    0.9843     48000
# weighted avg     0.9843    0.9843    0.9843     48000

# %%
# Save the trained model: This line of code is responsible for saving the model
# that has been trained using the trainer object. It will serialize the model
# and its associated weights, making it possible to reload and use the model
# in the future without the need to retrain it.
trainer.save_model()

# %%
# Import the 'pipeline' function from the 'transformers' library.
from transformers import pipeline

# Create a pipeline for image classification tasks.
# You need to specify the 'model_name' and the 'device' to use for inference.
# - 'model_name': The name of the pre-trained model to be used for image classification.
# - 'device': Specifies the device to use for running the model (0 for GPU, -1 for CPU).
pipe = pipeline('image-classification', model=model_name, device=0)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Device set to use cuda:0

# %%
# Accessing an image from the 'test_data' dataset using index 1.
image = test_data[1]["image"]

# Displaying the 'image' variable.
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=32x32>

# %%
# Apply the 'pipe' function to process the 'image' variable.
pipe(image)
# Out:
# [{'label': 'REAL', 'score': 0.9985968470573425},
#  {'label': 'FAKE', 'score': 0.0014031461905688047}]

# %%
# This line of code accesses the "label" attribute of a specific element in the test_data list.
# It's used to retrieve the actual label associated with a test data point.
id2label[test_data[1]["label"]]
# Out:
# 'REAL'
